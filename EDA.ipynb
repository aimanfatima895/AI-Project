# %% [markdown]
# <h1 style='background:purple; border:0; color:gold'><center>SUPERMARKET SALES</center><h1>

# %% [markdown]
# ![](supermarketoutside.jpg)

# %% [markdown]
# <h2 style='background:pink; border:0; color:sky blue'><center>EXPLORATORY DATA ANALYSIS</center><h2>
#
# 1. Data Cleaning & Exploration
# 2. Data Visualization

# %% [markdown]
# # **DATA EXPLORATION AND CLEANING**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sales = pd.read_csv('supermarket_sales - Sheet1.csv')

# %%
sales.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
sales.shape # To check number of rows and columns
# Out:
# (1000, 17)

# %%
sales.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
sales.dtypes
# Out:
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                      float64
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %%
sales.isnull().sum() # To check null values
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
sales['gross margin percentage'].unique()
# cogs - cost of goods sold
# Out:
# array([4.76190476])

# %%
sales.head(5)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross income  Rating
# 0  13:08      Ewallet  522.83       26.1415     9.1
# 1  10:29         Cash   76.40        3.8200     9.6
# ...

# %%
sales.describe()  # Statistical Summary
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross income      Rating
# count   1000.000000  1000.00000
# mean      15.379369     6.97270
# std       11.708825     1.71858
# min        0.508500     4.00000
# 25%        5.924875     5.50000
# 50%       12.088000     7.00000
# 75%       22.445250     8.50000
# max       49.650000    10.00000

# %% [markdown]
# # **DATA VISUALIZATION**

# %% [markdown]
# *Customer Type*

# %%
print(sales.shape)
sales['Customer type'].value_counts()
# Out:
# (1000, 16)
# Customer type
# Member    501
# Normal    499
# Name: count, dtype: int64

# %% [markdown]
# *Gender Count & Graph*

# %%
print(sales.shape)
sales['Gender'].value_counts()
# Out:
# (1000, 16)
# Gender
# Female    501
# Male      499
# Name: count, dtype: int64

# %%
plt.figure(dpi=125)
sns.countplot(sales['Gender'])
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Count of Gender')
A,B =sales.Gender.value_counts()

print('Male-',B)
print('Female -',A)

plt.show()
# Out:
# Male- 499
# Female - 501

# %% [markdown]
# *Graph Showing Product Type Sales Based on Genders*

# %%
plt.figure(dpi=125)
sns.countplot(y ='Product line', hue = "Gender", data = sales) 
plt.xlabel('Count')
plt.ylabel('Product Type')
plt.show()

# %% [markdown]
# *Graph Showing Most Busy Branch*

# %%
# Branch Count
plt.figure(dpi=125)
sns.countplot(sales['Branch'])
plt.xlabel('Branch Name')
plt.ylabel('Count')
plt.title('Which Branch is the most busy?')
A,B,C =sales.Branch.value_counts()

print('Branch A -',A)
print('Branch B -',C)
print('Branch C -',B)
      

plt.show()
# Out:
# Branch A - 340
# Branch B - 328
# Branch C - 332

# %% [markdown]
# *Graph Showing Most Used Payment Method*

# %%
plt.figure(dpi=125)
sns.countplot(sales['Payment'])
plt.xlabel('Payment Method')
plt.ylabel('Count')
plt.title('Which Payment Method is most used?')
A,B,C =sales.Payment.value_counts()

print('E-wallet -',A)
print('Cash -',B)
print('Credit Card -',C)
plt.show()
# Out:
# E-wallet - 345
# Cash - 344
# Credit Card - 311

# %% [markdown]
# *Graph Showing Comparison of Payment Method Between Branches*

# %%
plt.figure(dpi=125)
sns.countplot(y ='City', hue = "Payment", data = sales) 
plt.xlabel('Count')
plt.ylabel('Branches')
plt.show()

# %% [markdown]
# *Histogram Graph*

# %%
# Plotting Histogram for all
sales.hist(figsize=(12,12))
plt.show()

# %% [markdown]
# <h3 style='background:yellow; border:0; color:black'><center>**THANK YOU**</center><h3>
